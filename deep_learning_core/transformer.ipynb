# %% [markdown]
# casual masking

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_id = "HuggingFaceTB/SmolLM2-1.7B-Instruct"

tok = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id)

prompt = "Attention is all you need because"

inputs = tok(prompt, return_tensors="pt")

out = model.generate(
    **inputs,
    max_new_tokens=64,
    temperature=0.7,
    top_p=0.9,
    do_sample=True,
)

print(tok.decode(out[0], skip_special_tokens=True))
# Out:
# config.json:   0%|          | 0.00/908 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/3.76k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/801k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/655 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 3.42GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/218 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# Attention is all you need because we can't afford to pay all the attention to everybody. I don't want to hear about your problems because that's not my problem. You need to get over it."
#
# What can I do to improve the flow and clarity of this passage?

# %%
messages = [
    {
        "role": "user",
        "content": "Explain why attention is important in Transformer models."
    }
]

inputs = tok.apply_chat_template(
    messages,
    return_tensors="pt",
    add_generation_prompt=True,
    return_dict=True
)

out = model.generate(
    **inputs,
    max_new_tokens=100,
    temperature=0.7,
    top_p=0.9,
    do_sample=True
)

print(tok.decode(out[0], skip_special_tokens=True))
# Out:
# system
# You are a helpful AI assistant named SmolLM, trained by Hugging Face
# user
# Explain why attention is important in Transformer models.
# assistant
# Attention is a crucial component in Transformer models because it allows them to focus on specific parts of the input when generating output. In traditional RNNs, the model processes the entire sequence at once and then outputs a single sequence. However, this can lead to a problem known as "long-range dependence" where the model struggles to understand the relationship between tokens far apart in the sequence.
#
# In contrast, the Transformer model uses self-attention and multi-head attention mechanisms to allow the
